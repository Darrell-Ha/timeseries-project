# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./DataAirTrain.csv", index_col=0)

df['time'] = pd.to_datetime(df['time'])
df = df.set_index('time')
df.head()
# Out:
#                      Barometer   Temp     NO  PM-10     RH  Radiation  \
# time
# 2019-04-14 07:00:00    1010.28  25.55  18.57  18.12  98.55       0.01
# 2019-04-14 08:00:00    1011.21  25.17  11.61  17.25  99.62      32.83
# 2019-04-14 09:00:00    1012.36  25.86   8.79  12.04  97.46     311.73
# 2019-04-14 10:00:00    1012.66  27.67  11.33  10.91  88.45     532.91
# 2019-04-14 11:00:00    1012.78  29.14   5.50   8.91  77.99     610.51
#
#                      WindDir    SO2     NOx    NO2  ...  PM-2-5      CO  PM-1  \
# time                                                ...
# 2019-04-14 07:00:00   188.88  19.17  68.232  78.45  ...    7.48  461.82  3.43
# 2019-04-14 08:00:00   194.24  13.49  48.492  58.17  ...    7.63  595.40  3.43
# 2019-04-14 09:00:00   108.60   6.68  30.564  34.38  ...    5.31  553.42  2.43
# 2019-04-14 10:00:00   119.74   5.77  30.996  31.16  ...    4.48  446.55  2.14
# 2019-04-14 11:00:00   116.88   5.72  23.676  28.68  ...    3.68  435.10  1.87
#
# ...

# %%
import seaborn as sns

# %%
corr = df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr_df = corr.style.background_gradient(cmap = 'BrBG')

# %%
corr_df.to_excel("correlation.xlsx")

# %%
test_df = df.copy()

# %%
test_df[]
